# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
orts1 = np.load(
    "orthogonalities/ort_imagenet_ViT-B~16_train_image_1281167_512_4096_512_TopKReLU_64_False_False_0.0_cc3m_ViT-B~16_train_image_2905954_512_None_42h.npy"
)
orts2 = np.load(
    "orthogonalities/ort_imagenet_ViT-B~16_train_image_1281167_512_4096_512_TopKReLU_64_False_False_0.0_cc3m_ViT-B~16_train_image_2905954_512_DcorTopLatent_42h.npy"
)
# orts3 = np.load("orthogonalities/ort_imagenet_ViT-B~16_train_image_1281167_512_4096_512_TopKReLU_64_False_False_0.0_cc3m_ViT-B~16_train_image_2905954_512_DcorTopRecon_42h.npy")

plt.hist(orts1, bins=30, color="orange", alpha=0.8, density=True, label="None")
plt.hist(orts2, bins=30, color="green", alpha=0.8, density=True, label="dcor top latents")
# plt.hist(orts1, bins=30, color="orange", alpha=0.8, label="None")
# plt.hist(orts2, bins=30, color="green", alpha=0.8, label="dcor top latents")
plt.xlabel("Mean Cosine similarity")
plt.ylabel("Num of images in range")
plt.legend()
# plt.hist(orts3, bins=30, color='red', alpha=0.5)
plt.show()

# %%
orts1 = np.load("ort_imagenet100_clip_5000_512_4096_512_TopKReLU_64_False_False_0.0_cc3m_ViT-B~16_train_image_2905954_512_None_42h.npy")
orts2 = np.load("ort_imagenet100_clip_5000_512_4096_512_TopKReLU_64_False_False_0.0_cc3m_ViT-B~16_train_image_2905954_512_DcorTopLatent_42h.npy")
orts3 = np.load("ort_imagenet100_clip_5000_512_4096_512_TopKReLU_64_False_False_0.0_cc3m_ViT-B~16_train_image_2905954_512_DcorRandomLatent_42h.npy")

plt.hist(orts1, bins=30, color='green', alpha=0.8, label='none')
plt.hist(orts2, bins=30, color='red', alpha=0.8, label='dcor')
plt.hist(orts3, bins=30, color='orange', alpha=0.8, label='random')
plt.legend()
plt.show()
