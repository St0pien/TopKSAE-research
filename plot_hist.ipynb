# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = {
    "None": "orthogonalities/ort_imagenet_ViT-B~16_train_image_1281167_512_4096_512_TopKReLU_64_False_False_0.0_cc3m_ViT-B~16_train_image_2905954_512_None_42h.npy",
    "Ort": "orthogonalities/ort_imagenet_ViT-B~16_train_image_1281167_512_4096_512_TopKReLU_64_False_False_0.0_cc3m_ViT-B~16_train_image_2905954_512_Ort_42h.npy",
}

# %%
# plt.hist(orts1, bins=100, color="orange", alpha=0.8, density=True, label="None")
# plt.hist(orts2, bins=100, color="green", alpha=0.8, density=True, label="dcor top latents")

for k, path in data.items():
    v = np.load(path)
    plt.hist(v, bins=30, density=True, alpha=0.8, label=k)
plt.xlabel("Mean Cosine similarity")
plt.ylabel("Num of images in range")
plt.legend()
# plt.hist(orts3, bins=30, color='red', alpha=0.5)
plt.show()
